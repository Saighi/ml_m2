# %%
import numpy as np
import h5py
from tools.tools import *
from matplotlib import pyplot as plt 
from constant import *

# %%
h5_datas = h5py.File("../ml_project_data/h5/X_train.h5/X_train.h5","r")

# %%
sf = 50
demo_signal = h5_datas["eeg_1"][6]
time = np.arange(demo_signal.size) / sf
# plt.plot(demo_signal)

# %%
from PyEMD import EMD
s = np.random.random(100)
emd = EMD()
IMFs = emd(demo_signal)
IMFs.shape
# Out:
# (10, 1500)

# %%
plt.plot(IMFs[5])

# %%
plt.plot(np.array(split_in_bands(demo_signal,POWER_BANDS.values(),50)).T)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb328425bb0>,
#  <matplotlib.lines.Line2D at 0x7fb328425ca0>,
#  <matplotlib.lines.Line2D at 0x7fb328425d60>,
#  <matplotlib.lines.Line2D at 0x7fb328425e20>]
